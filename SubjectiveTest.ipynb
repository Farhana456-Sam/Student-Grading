# %%
import pandas as pd

# %%
df=  pd.read_csv('/content/drive/MyDrive/Subjective_Ques.csv')
students_df = pd.read_csv('/content/drive/MyDrive/Kerala_Students_Dataset.csv')

# %%
df.head()
# Out:
#                                             Question       Keyword 1  \
# 0  What is the importance of data preprocessing i...   Preprocessing
# 1  Explain the difference between classification ...  Classification
# 2  How does principal component analysis (PCA) wo...             PCA
# 3  What are the different types of activation fun...      Activation
# 4  Describe the bias-variance tradeoff in machine...            Bias
#
#         Keyword 2      Keyword 3       Keyword 4
# 0        Cleaning  Normalization  Transformation
# 1      Regression       Discrete      Continuous
# 2  Dimensionality       Variance     Eigenvalues
# 3            ReLU        Sigmoid            Tanh
# 4        Variance    Overfitting    Underfitting

# %%
df.isna().sum()
# Out:
# Question     0
# Keyword 1    0
# Keyword 2    0
# Keyword 3    0
# Keyword 4    0
# dtype: int64

# %%
 df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Question, Keyword 1, Keyword 2, Keyword 3, Keyword 4]
# Index: []

# %%
students_df.head()
# Out:
#    Student_ID         Full Name  Gender         DOB  Age Department  \
# 0        1000       Anika Verma  Female  16-04-2007   18    B.Pharm
# 1        1001      Ishita Sahni  Female  09-12-2002   23       B.Sc
# 2        1002  Aaryahi Malhotra    Male  13-11-2007   18        BCA
# 3        1003      Renee Mammen   Other  15-12-2003   22         BA
# 4        1004      Gokul Mander    Male  03-09-2005   20        BCA
#
#    Year of Study                              College Name  \
# 0              3                         Kannur University
# 1              2  APJ Abdul Kalam Technological University
# 2              4                      University of Kerala
# 3              2            Kerala Agricultural University
# 4              1                         Kannur University
#
#                          Email    Phone Number  ...  Assignments_Submitted  \
# 0       anikaverma65@gmail.com  +91 9290091641  ...                     56
# 1      ishitasahni69@gmail.com  +91 9914078254  ...                     94
# 2  aaryahimalhotra21@gmail.com  +91 8373592287  ...                     63
# 3      reneemammen27@gmail.com  +91 6931833405  ...                     89
# 4      gokulmander87@gmail.com  +91 6552982372  ...                     98
#
#    Participation_Score  Project_Grade  Skill_Proficiency  Quiz Mark  \
# 0                   68          99.29               8.92      33.62
# 1                   57          68.36               9.10      20.86
# 2                   75          80.20               7.46      30.84
# 3                   55          89.77               5.62      44.83
# 4                   55          78.46               5.34      36.53
#
#    Exam Grade  10th Mark% 12th Mark%         Login ID  Password
# 0           C       85.54      80.52  FYUGP2025100001    Ex@m20
# 1           D       65.78      56.09  FYUGP2025100002    Ex@m21
# 2           A       64.68      69.14  FYUGP2025100003    Ex@m22
# 3           B       76.22      75.40  FYUGP2025100004    Ex@m23
# 4           E       78.76      88.90  FYUGP2025100005    Ex@m24
#
# [5 rows x 22 columns]

# %%
students_df.isna().sum()
# Out:
# Student_ID               0
# Full Name                0
# Gender                   0
# DOB                      0
# Age                      0
# Department               0
# Year of Study            0
# College Name             0
# Email                    0
# Phone Number             0
# Attendance               0
# Projects                 0
# Assignments_Submitted    0
# Participation_Score      0
# Project_Grade            0
# Skill_Proficiency        0
# Quiz Mark                0
# Exam Grade               0
# 10th Mark%               0
# 12th Mark%               0
# Login ID                 0
# Password                 0
# dtype: int64

# %%
students_df[students_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Full Name, Gender, DOB, Age, Department, Year of Study, College Name, Email, Phone Number, Attendance, Projects, Assignments_Submitted, Participation_Score, Project_Grade, Skill_Proficiency, Quiz Mark, Exam Grade, 10th Mark%, 12th Mark%, Login ID, Password]
# Index: []
#
# [0 rows x 22 columns]

# %%
import getpass
# Dictionary to store student responses
responses = {}
results = []  # List to store evaluation results

def student_login():
    user_id = input("Enter your Student ID: ")
    password = getpass.getpass("Enter your Password: ")

    if ((students_df['Login ID'].astype(str) == user_id) & (students_df['Password'] == password)).any():
        print("Login Successful!")
        return user_id  # Keep as string to avoid conversion error
    else:
        print("Invalid login credentials!")
        return None
def attend_exam(student_id):
    print("\nAnswer the following questions:")
    responses[student_id] = []

    for i, row in df.iterrows():
        answer = input(f"Q{i+1}: {row['Question']}\nYour Answer: ")
        responses[student_id].append(answer)

def evaluate_responses():
  student_id = input("Enter Student ID to evaluate: ")

  if student_id in responses:
    total_marks = 0

    for i, ans in enumerate(responses[student_id]):
      question = df.iloc[i]['Question']
      key_list = df.iloc[i][['Keyword 1', 'Keyword 2', 'Keyword 3', 'Keyword 4']].dropna().tolist()
      match_count = sum(10 for key in key_list if key.strip().lower() in ans.lower())
      marks = min(match_count, 10)  # Max marks per answer is 10
      total_marks += marks
      print(f"Marks for Answer {i+10}: {marks} (Matched {match_count} keywords)")

    grade = assign_grade(total_marks)
    print(f"Total Marks: {total_marks}, Grade: {grade}")

    # Save student results
    results.append({
        "Student ID": student_id,
        "Answers": responses[student_id],
        "Total Marks": total_marks,
         "Grade": grade
        })
  else:
     print("No responses found for this student.")

def assign_grade(marks):
    if marks >= 90:
        return 'A+'
    elif marks >= 80:
        return 'A'
    elif marks >= 70:
        return 'B'
    elif marks >= 60:
        return 'C'
    else:
        return 'F'

def save_results():
    df = pd.DataFrame(results)
    df.to_csv('Student_Results.csv', index=False)
    print("Results saved successfully!")


# Main execution
student_id = student_login()
if student_id:
    attend_exam(student_id)
    print("\nExam Submitted! Awaiting evaluation.")

evaluate_responses()
save_results()
# Out:
# Enter your Student ID: FYUGP2025100001
# Enter your Password: ··········
# Login Successful!
#
# Answer the following questions:
# Q1: What is the importance of data preprocessing in machine learning?
# Your Answer: Preprocessing	Cleaning	Normalization	Transformation
# Q2: Explain the difference between classification and regression with examples.
# Your Answer: Classification	Regression	Discrete	Continuous
# Q3: How does principal component analysis (PCA) work, and when should it be used?
# Your Answer: PCA	Dimensionality	Variance	Eigenvalues
# Q4: What are the different types of activation functions in neural networks?
# Your Answer: Activation	ReLU	Sigmoid	Tanh
# Q5: Describe the bias-variance tradeoff in machine learning.
# Your Answer: Bias	Variance	Overfitting
# Q6: What are hyperparameters in machine learning, and how do they differ from model parameters?
# Your Answer: Hyperparameters	Parameters	Learning rate	Epochs
# Q7: Explain the concept of natural language processing (NLP) and its real-world applications.
# Your Answer: NLP	Text	Tokenization	Sentiment
# Q8: What is ensemble learning, and what are the common types of ensemble methods?
# Your Answer: Ensemble	Bagging	Boosting	Random Forest
# Q9: How does a convolutional neural network (CNN) work, and what are its main components?
# Your Answer: CNN	Convolution	Filters	Pooling
# Q10: Explain the significance of A/B testing in data science and how it is performed.
# Your Answer: A/B Testing	Experimentation	Hypothesis	Statistical significance
#
# Exam Submitted! Awaiting evaluation.
# Enter Student ID to evaluate: FYUGP2025100001
# Marks for Answer 10: 10 (Matched 40 keywords)
# Marks for Answer 11: 10 (Matched 40 keywords)
# Marks for Answer 12: 10 (Matched 40 keywords)
# Marks for Answer 13: 10 (Matched 40 keywords)
# Marks for Answer 14: 10 (Matched 30 keywords)
# Marks for Answer 15: 10 (Matched 40 keywords)
# Marks for Answer 16: 10 (Matched 40 keywords)
# Marks for Answer 17: 10 (Matched 40 keywords)
# Marks for Answer 18: 10 (Matched 40 keywords)
# Marks for Answer 19: 10 (Matched 40 keywords)
# Total Marks: 100, Grade: A+
# Results saved successfully!

# %%
data = pd.read_csv('/content/Student_Results.csv')

# %%
data.head()
# Out:
#         Student ID                                            Answers  \
# 0  FYUGP2025100001  ['Preprocessing\tCleaning\tNormalization\tTran...
#
#    Total Marks Grade
# 0          100    A+
